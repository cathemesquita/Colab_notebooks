# %% [markdown]
# <a href="https://colab.research.google.com/github/cathemesquita/Colab_notebooks/blob/main/VIDEO_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow

# %%
#(this will take a few minutes to install all the dependences!)
# !pip install "deeplabcut[tf]"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.3/296.3 kB 36.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.0/578.0 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 54.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 85.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 81.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 76.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import deeplabcut
# Out:
# Loading DLC 2.3.8...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %%
deeplabcut.__version__
# Out:
# '2.3.8'

# %%
#Setup your project variables:
# PLEASE EDIT THESE:


VideoType = 'mp4'

#don't edit these:
videofile_path = ['/content/drive/Shareddrives/Stress 1K/PROJETO LH PFC/STRESS_mPFC-CATHERINE-2023-12-10/videos/'] #Enter the list of videos or folder to analyze.


#This creates a path variable that links to your google drive copy
#No need to edit this, as you set it up before:
path_config_file = '/content/drive/Shareddrives/Stress 1K/PROJETO LH PFC/STRESS_mPFC-CATHERINE-2023-12-10/config.yaml'
# path_config_file

# %%
# deeplabcut.create_training_dataset(path_config_file, net_type='resnet_50', augmenter_type='imgaug')
# Out:
# /content/drive/Shareddrives/Stress 1K/PROJETO LH PFC/STRESS_mPFC-CATHERINE-2023-12-10/labeled-data/C�pia de CCM04_OF_POS_SCREEN/CollectedData_CATHERINE.h5  not found (perhaps not annotated).
# /content/drive/Shareddrives/Stress 1K/PROJETO LH PFC/STRESS_mPFC-CATHERINE-2023-12-10/labeled-data/C�pia de CCM192_OF_POS_SCREEN/CollectedData_CATHERINE.h5  not found (perhaps not annotated).
# /content/drive/Shareddrives/Stress 1K/PROJETO LH PFC/STRESS_mPFC-CATHERINE-2023-12-10/labeled-data/C�pia de CCM192_OF_PRE_SCREEN/CollectedData_CATHERINE.h5  not found (perhaps not annotated).
# /content/drive/Shareddrives/Stress 1K/PROJETO LH PFC/STRESS_mPFC-CATHERINE-2023-12-10/labeled-data/C�pia de CCM497_OpenField_2022-12-16-111331-0000/CollectedData_CATHERINE.h5  not found (perhaps not annotated).
# ...

# %%
# deeplabcut.train_network(path_config_file, shuffle=1, displayiters=100,saveiters=500)
# Out:
# Selecting single-animal trainer
# Config:
# {'all_joints': [[0], [1], [2], [3], [4]],
#  'all_joints_names': ['NOSE',
#                       'BASE_OF_NECK',
#                       'INTER_SCAPULA',
#                       'TORAX',
#                       'BASE_TAIL'],
#  'alpha_r': 0.02,
#  'apply_prob': 0.5,
#  'batch_size': 1,
#  'contrast': {'clahe': True,
#               'claheratio': 0.1,
#               'histeq': True,
#               'histeqratio': 0.1},
#  'convolution': {'edge': False,
#                  'emboss': {'alpha': [0.0, 1.0], 'strength': [0.5, 1.5]},
#                  'embossratio': 0.1,
#                  'sharpen': False,
#                  'sharpenratio': 0.3},
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets/iteration-0/UnaugmentedDataSet_STRESS_mPFCDec10/STRESS_mPFC_CATHERINE95shuffle1.mat',
#  'dataset_type': 'imgaug',
#  'decay_steps': 30000,
#  'deterministic': False,
#  'display_iters': 1000,
#  'fg_fraction': 0.25,
# ...
